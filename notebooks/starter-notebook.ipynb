# %% [markdown]
# # Create Data

# %%
# %%capture
# %%bash
python3 ./generate_data.py
python3 ./run_ddl.py

# %% [markdown]
# Run Python code as shown below

# %%
a = 10

# %% [markdown]
# Run SQL code as shown below, with the `%%sql` called magics

# %%
# %%sql
# select 1
# Out:
#    1
# 0  1

# %% [markdown]
# We use the `prod.db` schema where all our tables are create by `run_ddl.py`

# %%
# %%sql
# use prod_db
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Your code below

# %%
# %%sql
# WITH orders_cte AS (
#     SELECT
#         o_orderkey,
#         o_custkey,
#         o_orderstatus,
#         CAST(o_orderdate AS TIMESTAMP) AS o_orderdate,
#         o_orderpriority,
#         o_clerk,
#         o_shippriority,
#         o_comment,
#         o_totalprice
#     FROM orders
# ),
# stg_customers AS (
#     SELECT
#         c_custkey,
#         c_name,
#         c_address,
#         c_nationkey,
#         c_phone,
#         c_acctbal,
#         c_mktsegment,
#         c_comment
#     FROM customer
# ),
# nation_cte AS (
#     SELECT
#         CAST(n_nationkey AS INT) AS n_nationkey,
#         CAST(n_name AS STRING) AS n_name,
#         CAST(n_regionkey AS INT) AS n_regionkey,
#         CAST(n_comment AS STRING) AS n_comment
#     FROM nation
# ),
# dim_customers AS (
#     SELECT
#         c.c_custkey,
#         c.c_name,
#         c.c_address,
#         c.c_nationkey,
#         n.n_name AS nation_name,
#         c.c_phone,
#         c.c_acctbal,
#         c.c_mktsegment,
#         c.c_comment
#     FROM stg_customers c
#     INNER JOIN nation_cte n ON c.c_nationkey = n.n_nationkey
# )
# SELECT
#     o.o_orderkey,
#     o.o_custkey,
#     o.o_orderstatus,
#     o.o_orderdate,
#     o.o_orderpriority,
#     o.o_clerk,
#     o.o_shippriority,
#     o.o_totalprice,
#     c.c_name AS customer_name,
#     c.c_address AS customer_address,
#     c.c_phone AS customer_phone,
#     c.c_acctbal AS customer_account_balance,
#     c.c_mktsegment AS customer_market_segment,
#     c.nation_name AS customer_nation_name
# FROM orders_cte o
# INNER JOIN dim_customers c ON o.o_custkey = c.c_custkey;
# Out:
#      o_orderkey  o_custkey o_orderstatus o_orderdate  o_orderpriority  \
# 0           897       4894             P  1995-03-20         1-URGENT
# 1          4034       9233             F  1993-11-14  4-NOT SPECIFIED
# 2          4769      12044             P  1995-04-14  4-NOT SPECIFIED
# 3          5123        964             O  1998-02-10         1-URGENT
# 4          6695       1697             F  1992-06-28            5-LOW
# ..          ...        ...           ...         ...              ...
# 995      364326       3106             O  1995-04-20  4-NOT SPECIFIED
# 996      364518      11495             O  1998-01-22  4-NOT SPECIFIED
# 997      364707        191             F  1992-07-06         3-MEDIUM
# 998      364868       2173             F  1993-02-22            5-LOW
# 999      365666         65             O  1997-03-25            5-LOW
#
#              o_clerk  o_shippriority o_totalprice       customer_name  \
# 0    Clerk#000000316               0     66775.72  Customer#000004894
# 1    Clerk#000000548               0    307637.71  Customer#000009233
# 2    Clerk#000000116               0    206126.35  Customer#000012044
# 3    Clerk#000000776               0     18908.75  Customer#000000964
# 4    Clerk#000000877               0    322140.76  Customer#000001697
# ..               ...             ...          ...                 ...
# 995  Clerk#000000718               0     60631.19  Customer#000003106
# 996  Clerk#000000006               0    167994.44  Customer#000011495
# 997  Clerk#000000198               0    225342.25  Customer#000000191
# 998  Clerk#000000028               0    216130.35  Customer#000002173
# 999  Clerk#000000856               0    117900.04  Customer#000000065
#
#                              customer_address   customer_phone  \
# 0             qccDi3BeqTSkIJKsp21j4KBsQpPk0Gt  30-152-685-8820
# 1                   1Ba3hAO5jmBFJpKq2QIdZlb3Z  33-327-912-9200
# 2                                u9bevlA h3PS  10-488-427-2414
# 3             2DpdvfAw4TuXl8DV,YVBwGsK7oLzkYr  22-974-772-2802
# 4                       8aHZSJIoZKtIfcD8IFMCu  34-288-313-5272
# ..                                        ...              ...
# 995                           fB4v6LYmL9gsNuV  28-957-973-3423
# 996             IqHoDhNpTHKIyWfDQqptGnUmZswWO  12-863-558-5251
# 997                         cZMo3 b4GwZtUmdbw  26-811-707-6869
# 998                 ITNmLWncdNgMxHBsOfoSGKeu0  20-146-331-2592
# 999  ak7rtta,tWG,jR,cTSXflW6RVQ3alna3P4Q,zF03  33-733-623-5267
#
#     customer_account_balance customer_market_segment customer_nation_name
# 0                    7927.44               HOUSEHOLD         SAUDI ARABIA
# 1                    4227.72               FURNITURE       UNITED KINGDOM
# 2                    4825.26               MACHINERY              ALGERIA
# 3                    4756.58               FURNITURE                JAPAN
# 4                    -913.24               FURNITURE        UNITED STATES
# ..                       ...                     ...                  ...
# 995                  -295.64               HOUSEHOLD                CHINA
# 996                  4111.59               FURNITURE               BRAZIL
# 997                  2945.16                BUILDING           MOZAMBIQUE
# 998                  7684.96              AUTOMOBILE                 IRAN
# 999                  8795.16              AUTOMOBILE       UNITED KINGDOM
#
# [1000 rows x 14 columns]

# %%
# %%sql
#
# select * from region;
# Out:
#    r_regionkey       r_name                                          r_comment
# 0            0       AFRICA  ar packages. regular excuses among the ironic ...
# 1            1      AMERICA                    s are. furiously even pinto bea
# 2            2         ASIA                    c, special dependencies around
# 3            3       EUROPE      e dolphins are furiously about the carefully
# 4            4  MIDDLE EAST   foxes boost furiously along the carefully dog...

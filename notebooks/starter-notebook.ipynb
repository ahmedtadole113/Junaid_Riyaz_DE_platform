# %% [markdown]
# # Create Data

# %%
# %%capture
# %%bash
python3 ./generate_data.py
python3 ./run_ddl.py

# %% [markdown]
# Run Python code as shown below

# %%
a = 10

# %% [markdown]
# Run SQL code as shown below, with the `%%sql` called magics

# %%
# %%sql
# select 1
# Out:
#    1
# 0  1

# %% [markdown]
# We use the `prod.db` schema where all our tables are create by `run_ddl.py`

# %%
# %%sql
# use prod_db
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Your code below

# %%
# %%sql
# WITH orders_cte AS (
#     SELECT
#         o_orderkey,
#         o_custkey,
#         o_orderstatus,
#         CAST(o_orderdate AS TIMESTAMP) AS o_orderdate,
#         o_orderpriority,
#         o_clerk,
#         o_shippriority,
#         o_comment,
#         o_totalprice
#     FROM orders
# ),
# stg_customers AS (
#     SELECT
#         c_custkey,
#         c_name,
#         c_address,
#         c_nationkey,
#         c_phone,
#         c_acctbal,
#         c_mktsegment,
#         c_comment
#     FROM customer
# ),
# nation_cte AS (
#     SELECT
#         CAST(n_nationkey AS INT) AS n_nationkey,
#         CAST(n_name AS STRING) AS n_name,
#         CAST(n_regionkey AS INT) AS n_regionkey,
#         CAST(n_comment AS STRING) AS n_comment
#     FROM nation
# ),
# dim_customers AS (
#     SELECT
#         c.c_custkey,
#         c.c_name,
#         c.c_address,
#         c.c_nationkey,
#         n.n_name AS nation_name,
#         c.c_phone,
#         c.c_acctbal,
#         c.c_mktsegment,
#         c.c_comment
#     FROM stg_customers c
#     INNER JOIN nation_cte n ON c.c_nationkey = n.n_nationkey
# )
# SELECT
#     o.o_orderkey,
#     o.o_custkey,
#     o.o_orderstatus,
#     o.o_orderdate,
#     o.o_orderpriority,
#     o.o_clerk,
#     o.o_shippriority,
#     o.o_totalprice,
#     c.c_name AS customer_name,
#     c.c_address AS customer_address,
#     c.c_phone AS customer_phone,
#     c.c_acctbal AS customer_account_balance,
#     c.c_mktsegment AS customer_market_segment,
#     c.nation_name AS customer_nation_name
# FROM orders_cte o
# INNER JOIN dim_customers c ON o.o_custkey = c.c_custkey;
# Out:
#      o_orderkey  o_custkey o_orderstatus o_orderdate  o_orderpriority  \
# 0            71        338             O  1998-01-24  4-NOT SPECIFIED
# 1           167      11941             F  1993-01-04  4-NOT SPECIFIED
# 2           195      13543             F  1993-12-28         3-MEDIUM
# 3           260      10474             O  1996-12-10         3-MEDIUM
# 4           261       4609             F  1993-06-29         3-MEDIUM
# ..          ...        ...           ...         ...              ...
# 995       43425       1972             F  1994-01-13            5-LOW
# 996       43429       8063             F  1992-07-06            5-LOW
# 997       43461       3079             O  1998-02-25         1-URGENT
# 998       43492      14741             O  1996-03-17  4-NOT SPECIFIED
# 999       43495       8806             O  1996-10-28  4-NOT SPECIFIED
#
#              o_clerk  o_shippriority o_totalprice       customer_name  \
# 0    Clerk#000000271               0    244449.86  Customer#000000338
# 1    Clerk#000000731               0     53697.73  Customer#000011941
# 2    Clerk#000000216               0    169343.52  Customer#000013543
# 3    Clerk#000000960               0    242001.54  Customer#000010474
# 4    Clerk#000000310               0    271008.54  Customer#000004609
# ..               ...             ...          ...                 ...
# 995  Clerk#000000547               0     82022.85  Customer#000001972
# 996  Clerk#000000436               0    210139.31  Customer#000008063
# 997  Clerk#000000451               0    160349.02  Customer#000003079
# 998  Clerk#000000295               0     88874.75  Customer#000014741
# 999  Clerk#000000961               0    235947.34  Customer#000008806
#
#                            customer_address   customer_phone  \
# 0    sQI2qN4Ki,DGk8hxTcKwhAewbgJulXQF7SHDz3  33-302-620-7535
# 1            TlPsiievQdmQvqpRrPtY00ZPxI8Q5t  17-483-791-2189
# 2               CDFKhu1hAX EqpuBJrA xbHkyxd  25-595-249-6287
# 3                   L5jU7sgb4oKtcDLq5mxbu6B  15-163-487-9110
# 4        6S5SQtVa mh7,IPxIepoaCjB9N6gDFWbBt  25-198-400-5775
# ..                                      ...              ...
# 995                 04QQayQK1ZhRmUXBF8vV9pG  17-991-532-5136
# 996              VTgovJ7hWsoX2dgSzY,hKDm,OC  19-360-212-3816
# 997                   DOsHduEU0klJUyT74U ly  31-831-777-9971
# 998        HXY6ihKeRzUyvoRCp74qf6nOJaICRMn3  26-259-950-7740
# 999    xCx4qU3joqaCAQy VeDBcjR fhkEKlZD9bj7  21-218-507-7405
#
#     customer_account_balance customer_market_segment customer_nation_name
# 0                    4092.49               FURNITURE       UNITED KINGDOM
# 1                    8812.05                BUILDING              GERMANY
# 2                    9793.30               FURNITURE              MOROCCO
# 3                    7427.66               MACHINERY             ETHIOPIA
# 4                     820.04               MACHINERY              MOROCCO
# ..                       ...                     ...                  ...
# 995                   689.12              AUTOMOBILE              GERMANY
# 996                  7451.49               MACHINERY            INDONESIA
# 997                  9592.43               FURNITURE              VIETNAM
# 998                  3855.03               MACHINERY           MOZAMBIQUE
# 999                  7293.45               FURNITURE                 IRAQ
#
# [1000 rows x 14 columns]

# %%
# %%sql
#
# select * from region;
# Out:
#    r_regionkey       r_name                                          r_comment
# 0            0       AFRICA  ar packages. regular excuses among the ironic ...
# 1            1      AMERICA                    s are. furiously even pinto bea
# 2            2         ASIA                    c, special dependencies around
# 3            3       EUROPE      e dolphins are furiously about the carefully
# 4            4  MIDDLE EAST   foxes boost furiously along the carefully dog...
